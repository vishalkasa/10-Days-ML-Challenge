# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("time_series_2019-ncov-Confirmed.csv")
df=df.rename(columns={'Province/State':'State','Country/Region':'Country'})
df
# Out:
#     State      Country      Lat      Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0     NaN     Thailand  15.0000  101.0000        2        3        5        7
# 1     NaN        Japan  36.0000  138.0000        2        1        2        2
# 2     NaN    Singapore   1.2833  103.8333        0        1        3        3
# 3     NaN        Nepal  28.1667   84.2500        0        0        0        1
# 4     NaN     Malaysia   2.5000  112.5000        0        0        0        3
# ..    ...          ...      ...       ...      ...      ...      ...      ...
# 482   NaN     Dominica  15.4150  -61.3710        0        0        0        0
# 483   NaN      Grenada  12.1165  -61.6790        0        0        0        0
# 484   NaN   Mozambique -18.6657   35.5296        0        0        0        0
# 485   NaN        Syria  34.8021   38.9968        0        0        0        0
# 486   NaN  Timor-Leste  -8.8742  125.7275        0        0        0        0
#
#      1/26/20  1/27/20  ...  3/13/20  3/14/20  3/15/20  3/16/20  3/17/20  \
# 0          8        8  ...       75       82      114      147      177
# 1          4        4  ...      701      773      839      825      878
# 2          4        5  ...      200      212      226      243      266
# 3          1        1  ...        1        1        1        1        1
# 4          4        4  ...      197      238      428      566      673
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 482        0        0  ...        0        0        0        0        0
# 483        0        0  ...        0        0        0        0        0
# 484        0        0  ...        0        0        0        0        0
# 485        0        0  ...        0        0        0        0        0
# 486        0        0  ...        0        0        0        0        0
#
#      3/18/20  3/19/20  3/20/20  3/21/20  3/22/20
# 0        212      272      322      411      599
# 1        889      924      963     1007     1086
# 2        313      345      385      432      455
# 3          1        1        1        1        2
# 4        790      900     1030     1183     1306
# ..       ...      ...      ...      ...      ...
# 482        0        0        0        0        1
# 483        0        0        0        0        1
# 484        0        0        0        0        1
# 485        0        0        0        0        1
# 486        0        0        0        0        1
#
# [487 rows x 65 columns]

# %%
x=df.copy()
ls=[]
for i in range(4,65):
    m=x.iloc[:,i].value_counts()
    if(m[0]>341):
        ls.append(i)
df.drop(df.columns[ls],axis=1,inplace=True)
df
# Out:
#     State      Country      Lat      Long  3/4/20  3/5/20  3/6/20  3/7/20  \
# 0     NaN     Thailand  15.0000  101.0000      43      47      48      50
# 1     NaN        Japan  36.0000  138.0000     331     360     420     461
# 2     NaN    Singapore   1.2833  103.8333     110     117     130     138
# 3     NaN        Nepal  28.1667   84.2500       1       1       1       1
# 4     NaN     Malaysia   2.5000  112.5000      50      50      83      93
# ..    ...          ...      ...       ...     ...     ...     ...     ...
# 482   NaN     Dominica  15.4150  -61.3710       0       0       0       0
# 483   NaN      Grenada  12.1165  -61.6790       0       0       0       0
# 484   NaN   Mozambique -18.6657   35.5296       0       0       0       0
# 485   NaN        Syria  34.8021   38.9968       0       0       0       0
# 486   NaN  Timor-Leste  -8.8742  125.7275       0       0       0       0
#
#      3/8/20  3/9/20  ...  3/13/20  3/14/20  3/15/20  3/16/20  3/17/20  \
# 0        50      50  ...       75       82      114      147      177
# 1       502     511  ...      701      773      839      825      878
# 2       150     150  ...      200      212      226      243      266
# 3         1       1  ...        1        1        1        1        1
# 4        99     117  ...      197      238      428      566      673
# ..      ...     ...  ...      ...      ...      ...      ...      ...
# 482       0       0  ...        0        0        0        0        0
# 483       0       0  ...        0        0        0        0        0
# 484       0       0  ...        0        0        0        0        0
# 485       0       0  ...        0        0        0        0        0
# 486       0       0  ...        0        0        0        0        0
#
#      3/18/20  3/19/20  3/20/20  3/21/20  3/22/20
# 0        212      272      322      411      599
# 1        889      924      963     1007     1086
# 2        313      345      385      432      455
# 3          1        1        1        1        2
# 4        790      900     1030     1183     1306
# ..       ...      ...      ...      ...      ...
# 482        0        0        0        0        1
# 483        0        0        0        0        1
# 484        0        0        0        0        1
# 485        0        0        0        0        1
# 486        0        0        0        0        1
#
# [487 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 487 entries, 0 to 486
# Data columns (total 23 columns):
# State      325 non-null object
# Country    487 non-null object
# Lat        487 non-null float64
# Long       487 non-null float64
# 3/4/20     487 non-null int64
# 3/5/20     487 non-null int64
# 3/6/20     487 non-null int64
# 3/7/20     487 non-null int64
# 3/8/20     487 non-null int64
# 3/9/20     487 non-null int64
# 3/10/20    487 non-null int64
# 3/11/20    487 non-null int64
# 3/12/20    487 non-null int64
# 3/13/20    487 non-null int64
# 3/14/20    487 non-null int64
# 3/15/20    487 non-null int64
# 3/16/20    487 non-null int64
# 3/17/20    487 non-null int64
# 3/18/20    487 non-null int64
# 3/19/20    487 non-null int64
# 3/20/20    487 non-null int64
# 3/21/20    487 non-null int64
# 3/22/20    487 non-null int64
# dtypes: float64(2), int64(19), object(2)
# memory usage: 87.6+ KB

# %%
df.isnull().sum()
# Out:
# State      162
# Country      0
# Lat          0
# Long         0
# 3/4/20       0
# 3/5/20       0
# 3/6/20       0
# 3/7/20       0
# 3/8/20       0
# 3/9/20       0
# 3/10/20      0
# 3/11/20      0
# 3/12/20      0
# 3/13/20      0
# 3/14/20      0
# 3/15/20      0
# 3/16/20      0
# 3/17/20      0
# 3/18/20      0
# 3/19/20      0
# 3/20/20      0
# 3/21/20      0
# 3/22/20      0
# dtype: int64

# %%
plt.figure(figsize=(6,14))
plt.barh(df["Country"],df["3/18/20"],color="green")
plt.yticks(fontsize=7.5)
plt.ylabel("Country")
plt.xlabel("Cases")
plt.title("Corona cases on 3/18/20")
plt.show()

# %%
x=list(set(df.columns)-set(['State','Country','Lat','Long']))
plt.xlabel("Cases")
plt.ylabel("Dates")
plt.title("Cases in Japan")
plt.plot(df.iloc[1,4:23],x,color="red")

# %%
df.dropna(axis=0,how='any',inplace=True)

# %%
df
# Out:
#                      State         Country      Lat      Long  3/4/20  3/5/20  \
# 5         British Columbia          Canada  49.2827 -123.1207      12      13
# 6          New South Wales       Australia -33.8688  151.2093      22      22
# 7                 Victoria       Australia -37.8136  144.9631      10      10
# 8               Queensland       Australia -28.0167  153.4000      11      13
# 19         South Australia       Australia -34.9285  138.6007       5       5
# ..                     ...             ...      ...       ...     ...     ...
# 462          New Caledonia          France -20.9043  165.6180       0       0
# 463                Bermuda  United Kingdom  32.3078  -64.7505       0       0
# 472           Sint Maarten     Netherlands  18.0425  -63.0548       0       0
# 475            Isle of Man  United Kingdom  54.2361   -4.5481       0       0
# 477  Northwest Territories          Canada  64.8255 -124.8457       0       0
#
#      3/6/20  3/7/20  3/8/20  3/9/20  ...  3/13/20  3/14/20  3/15/20  3/16/20  \
# 5        21      21      27      32  ...       64       64       73      103
# 6        26      28      38      48  ...       92      112      134      171
# 7        10      11      11      15  ...       36       49       57       71
# 8        13      13      15      15  ...       35       46       61       68
# 19        7       7       7       7  ...       16       19       20       29
# ..      ...     ...     ...     ...  ...      ...      ...      ...      ...
# 462       0       0       0       0  ...        0        0        0        0
# 463       0       0       0       0  ...        0        0        0        0
# 472       0       0       0       0  ...        0        0        0        0
# 475       0       0       0       0  ...        0        0        0        0
# 477       0       0       0       0  ...        0        0        0        0
#
#      3/17/20  3/18/20  3/19/20  3/20/20  3/21/20  3/22/20
# 5        103      186      231      271      424      424
# 6        210      267      307      353      436      533
# 7         94      121      121      121      229      296
# 8         78       94      144      184      221      221
# 19        29       37       42       50       67      100
# ..       ...      ...      ...      ...      ...      ...
# 462        0        0        2        2        4        4
# 463        0        0        2        2        2        2
# 472        0        0        0        1        1        1
# 475        0        0        0        1        1        5
# 477        0        0        0        0        1        1
#
# [325 rows x 23 columns]

# %%
asia = pd.read_csv("as_countries.csv")
eu = pd.read_csv("eu_countries.csv")
af = pd.read_csv("af_countries.csv")
na = pd.read_csv("na_countries.csv")
sa = pd.read_csv("sa_countries.csv")
as_count = asia['name'].values.tolist()
eu_count = eu['name'].values.tolist()
af_count = af['name'].values.tolist()
na_count = na['name'].values.tolist()
sa_count = sa['name'].values.tolist()

# %%
cases = df["3/18/20"]
countries = df["Country"]

# %%
ind = 0
as_cases = 0
eu_cases = 0
af_cases = 0
na_cases = 0
sa_cases = 0
for i in countries:
    if i in as_count:
        as_cases+=cases[ind]
    if i in eu_count:
        eu_cases+=cases[ind]
    if i in af_count:
        af_cases+=cases[ind]
    if i in na_count:
        na_cases+=cases[ind]
    if i in sa_count:
        sa_cases+=cases[ind]
    ind=ind+1

# %%
cases=[as_cases, eu_cases, af_cases, na_cases, sa_cases]
continent = ['Asia', 'Europe', 'Africa', "North America", "South America"]
plt.barh(continent,cases,color="Green")
plt.show()
